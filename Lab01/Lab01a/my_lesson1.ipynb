# %% [markdown]
# # Thuc hanh tri tue nhan tao Buoi 1
# ## Noi dung thuc hanh

# %% [markdown]
# ### In chu ra man hinh

# %% [markdown]
# # lenh 1 - xuat chu
# print('Hello, Python World!')

# %% [markdown]
# ### Chay tap tin python

# %%
# !python ex0_hello_world.py
# Out:
# Hello, Python World!

# %%
# %run ex0_hello_world.py
# Out:
# Hello, Python World!

# %%
# %run ex1_calc.py
# Out:
# Calculator Basic
# Moi ban nhap so a:  9
# Moi ban nhap so b:  9
# c = 9 + 9 = 18

# %%
print("Calculator Basic")
a = int(input("Moi ban nhap so a: "))
b = int(input("Moi ban nhap so b: "))
c = a + b
print("c = %d + %d = %d" % (a, b, c))
# Out:
# Calculator Basic
# Moi ban nhap so a:  9
# Moi ban nhap so b:  8
# c = 9 + 8 = 17

# %%
# %run ex3_circle.py
# Out:
# Nhap ban kinh hìn tron:
#  9
# Chu vi hinh tron la:  56.5488
# Dien tich hinh tron la:  254.34

# %%
print('Nhap ban kinh hìn tron: ')
r= float(input())
cv = 2*3.1416*r
dt=3.14*r*r
print('Chu vi hinh tron la: ',cv)
print('Dien tich hinh tron la: ',dt)
# Out:
# Nhap ban kinh hìn tron:
#  8
# Chu vi hinh tron la:  50.2656
# Dien tich hinh tron la:  200.96
